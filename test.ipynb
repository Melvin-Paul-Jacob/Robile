# %% [markdown]
# <a href="https://colab.research.google.com/github/Melvin-Paul-Jacob/Robile/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image(filename='0001.jpg')

# %%
from IPython.display import Image
Image(filename='0002.jpg')

# %%
from IPython.display import Image
Image(filename='0003.jpg')

# %%
from IPython.display import Image
Image(filename='0004.jpg')

# %%
from IPython.display import Image
Image(filename='0005.jpg')

# %%
from IPython.display import Image
Image(filename='0006.jpg')

# %%
from IPython.display import Image
Image(filename='0007.jpg')

# %%
from IPython.display import Image
Image(filename='0008.jpg')

# %%
from IPython.display import Image
Image(filename='0009.jpg')

# %%
from IPython.display import Image
Image(filename='0010.jpg')

# %%
from google.colab import drive
drive.mount('/content/drive')
